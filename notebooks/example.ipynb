# %% [markdown]
# # Session 1 notebook demo
#
# This notebook is a client of the project package. The durable workflow logic still lives in `src/nextgen2026_coding_bootcamp/`.

# %%
from nextgen2026_coding_bootcamp.viz import make_summary

summary = make_summary()
summary

# %%
summary.assign(mean_reading=summary["mean_reading"].round(2))

# %% [markdown]
# The rule is simple: if the logic matters later, move it into `src/` and import it here.
