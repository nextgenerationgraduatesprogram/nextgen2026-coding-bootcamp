# %% [markdown]
# # Session 1 notebook demo
#
# This notebook is a client of the project package.

# %%
import sys
print(sys.executable)
print("Kernel is working")

# %%
from nextgen2026_coding_bootcamp.viz import make_summary

summary = make_summary()
summary

# %%
summary.assign(mean_reading=summary["mean_reading"].round(2))

# %% [markdown]
# ### Visualizing the data directly in the notebook
# We can also import the plotting logic from `viz.py` and display it here.

# %%
from nextgen2026_coding_bootcamp.viz import make_plot
import matplotlib.pyplot as plt

# Using the summary we already have
ax = make_plot(summary)
plt.show()
